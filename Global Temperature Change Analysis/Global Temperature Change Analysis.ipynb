# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("allcountriesglobaltemperaturechange.csv")

# %%
df
# Out:
#      ObjectId                  Country Name            Unit  \
# 0           1  Afghanistan, Islamic Rep. of  Degree Celsius
# 1           2                       Albania  Degree Celsius
# 2           3                       Algeria  Degree Celsius
# 3           4                American Samoa  Degree Celsius
# 4           5      Andorra, Principality of  Degree Celsius
# ..        ...                           ...             ...
# 222       223                Western Sahara  Degree Celsius
# 223       224                         World  Degree Celsius
# 224       225                Yemen, Rep. of  Degree Celsius
# 225       226                        Zambia  Degree Celsius
# 226       230                      Zimbabwe  Degree Celsius
#
#                         Change    1970   1971   1972   1973   1974   1975  \
# 0    Surface Temperature Change  0.898  0.652 -1.089  0.262 -0.470 -0.468
# 1    Surface Temperature Change -0.119 -0.200 -0.077 -0.299 -0.134 -0.203
# 2    Surface Temperature Change  0.114 -0.380 -0.342 -0.028 -0.502 -0.554
# 3    Surface Temperature Change -0.036 -0.473 -0.070  0.322 -0.317 -0.128
# 4    Surface Temperature Change  0.081 -0.355 -0.526 -0.010 -0.412  0.207
# ..                          ...    ...    ...    ...    ...    ...    ...
# 222  Surface Temperature Change  0.547 -0.620 -1.104 -0.013 -0.600 -0.267
# 223  Surface Temperature Change  0.153 -0.089 -0.193  0.271 -0.179  0.091
# 224  Surface Temperature Change  0.388 -0.199  0.049  0.333 -0.108  0.031
# 225  Surface Temperature Change  0.354 -0.249 -0.146  0.386 -0.393 -0.116
# 226  Surface Temperature Change  0.427 -0.033 -0.367  0.627 -0.471 -0.253
#
#      ...   2012   2013   2014   2015   2016   2017   2018   2019   2020   2021
# 0    ...  0.234  1.308  0.457  1.101  1.607  1.568  1.580  0.960  0.544  1.421
# 1    ...  1.568  1.444  1.322  1.665  1.601  1.269  2.146  1.823  1.623  1.682
# 2    ...  1.128  1.173  1.676  1.101  1.736  1.498  1.211  1.094  1.913  2.317
# 3    ...  0.646  0.883  0.554  0.394  0.924  0.820  0.574  0.924  0.815  0.653
# 4    ...  1.196  0.757  1.857  1.546  1.830  1.771  1.761  1.813  2.401  1.367
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 222  ...  1.234  1.282  1.244  1.277  1.636  2.078  0.851  1.430  2.026  1.557
# 223  ...  1.058  1.007  1.042  1.406  1.658  1.424  1.284  1.449  1.713  1.442
# 224  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 225  ...  0.926  0.746  0.638  1.486  1.474  0.721  0.727  1.295  1.252  1.002
# 226  ...  0.329  0.102 -0.008  0.808  1.051  0.116  0.405  0.939  0.415 -0.101
#
# [227 rows x 56 columns]

# %%
df.head()
# Out:
#    ObjectId                  Country Name            Unit  \
# 0         1  Afghanistan, Islamic Rep. of  Degree Celsius
# 1         2                       Albania  Degree Celsius
# 2         3                       Algeria  Degree Celsius
# 3         4                American Samoa  Degree Celsius
# 4         5      Andorra, Principality of  Degree Celsius
#
#                       Change    1970   1971   1972   1973   1974   1975  ...  \
# 0  Surface Temperature Change  0.898  0.652 -1.089  0.262 -0.470 -0.468  ...
# 1  Surface Temperature Change -0.119 -0.200 -0.077 -0.299 -0.134 -0.203  ...
# 2  Surface Temperature Change  0.114 -0.380 -0.342 -0.028 -0.502 -0.554  ...
# 3  Surface Temperature Change -0.036 -0.473 -0.070  0.322 -0.317 -0.128  ...
# 4  Surface Temperature Change  0.081 -0.355 -0.526 -0.010 -0.412  0.207  ...
#
#     2012   2013   2014   2015   2016   2017   2018   2019   2020   2021
# 0  0.234  1.308  0.457  1.101  1.607  1.568  1.580  0.960  0.544  1.421
# 1  1.568  1.444  1.322  1.665  1.601  1.269  2.146  1.823  1.623  1.682
# 2  1.128  1.173  1.676  1.101  1.736  1.498  1.211  1.094  1.913  2.317
# 3  0.646  0.883  0.554  0.394  0.924  0.820  0.574  0.924  0.815  0.653
# 4  1.196  0.757  1.857  1.546  1.830  1.771  1.761  1.813  2.401  1.367
#
# [5 rows x 56 columns]

# %%
df.shape
# Out:
# (227, 56)

# %%
df.isnull().sum()
# Out:
# ObjectId         0
# Country Name     0
# Unit             0
# Change           0
# 1970            37
# 1971            34
# 1972            32
# 1973            32
# 1974            34
# 1975            37
# 1976            35
# 1977            36
# 1978            35
# 1979            36
# 1980            34
# 1981            35
# 1982            35
# 1983            38
# 1984            37
# 1985            37
# 1986            36
# 1987            36
# 1988            36
# 1989            35
# 1990            36
# 1991            37
# 1992            16
# 1993            18
# 1994            18
# 1995            16
# 1996            16
# 1997            19
# 1998            15
# 1999            17
# 2000            16
# 2001            18
# 2002            15
# 2003            12
# 2004            13
# 2005            14
# 2006            11
# 2007            10
# 2008            14
# 2009            13
# 2010            12
# 2011            10
# 2012            13
# 2013            11
# 2014            11
# 2015            11
# 2016            12
# 2017            13
# 2018            11
# 2019            12
# 2020            13
# 2021            13
# dtype: int64

# %%
df.columns.tolist()
# Out:
# ['ObjectId',
#  'Country Name',
#  'Unit',
#  'Change ',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021']

# %%
# Filling the BLank data using interpolation method 
year_columns = df.columns[4:]  
df[year_columns] = df[year_columns].apply(pd.to_numeric, errors='coerce')
df[year_columns] = df[year_columns].interpolate(method='linear', axis=1, limit_direction='both')

# %%
df
# Out:
#      ObjectId                  Country Name            Unit  \
# 0           1  Afghanistan, Islamic Rep. of  Degree Celsius
# 1           2                       Albania  Degree Celsius
# 2           3                       Algeria  Degree Celsius
# 3           4                American Samoa  Degree Celsius
# 4           5      Andorra, Principality of  Degree Celsius
# ..        ...                           ...             ...
# 222       223                Western Sahara  Degree Celsius
# 223       224                         World  Degree Celsius
# 224       225                Yemen, Rep. of  Degree Celsius
# 225       226                        Zambia  Degree Celsius
# 226       230                      Zimbabwe  Degree Celsius
#
#                         Change    1970   1971   1972   1973   1974   1975  \
# 0    Surface Temperature Change  0.898  0.652 -1.089  0.262 -0.470 -0.468
# 1    Surface Temperature Change -0.119 -0.200 -0.077 -0.299 -0.134 -0.203
# 2    Surface Temperature Change  0.114 -0.380 -0.342 -0.028 -0.502 -0.554
# 3    Surface Temperature Change -0.036 -0.473 -0.070  0.322 -0.317 -0.128
# 4    Surface Temperature Change  0.081 -0.355 -0.526 -0.010 -0.412  0.207
# ..                          ...    ...    ...    ...    ...    ...    ...
# 222  Surface Temperature Change  0.547 -0.620 -1.104 -0.013 -0.600 -0.267
# 223  Surface Temperature Change  0.153 -0.089 -0.193  0.271 -0.179  0.091
# 224  Surface Temperature Change  0.388 -0.199  0.049  0.333 -0.108  0.031
# 225  Surface Temperature Change  0.354 -0.249 -0.146  0.386 -0.393 -0.116
# 226  Surface Temperature Change  0.427 -0.033 -0.367  0.627 -0.471 -0.253
#
#      ...   2012   2013   2014   2015   2016   2017   2018   2019   2020   2021
# 0    ...  0.234  1.308  0.457  1.101  1.607  1.568  1.580  0.960  0.544  1.421
# 1    ...  1.568  1.444  1.322  1.665  1.601  1.269  2.146  1.823  1.623  1.682
# 2    ...  1.128  1.173  1.676  1.101  1.736  1.498  1.211  1.094  1.913  2.317
# 3    ...  0.646  0.883  0.554  0.394  0.924  0.820  0.574  0.924  0.815  0.653
# 4    ...  1.196  0.757  1.857  1.546  1.830  1.771  1.761  1.813  2.401  1.367
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 222  ...  1.234  1.282  1.244  1.277  1.636  2.078  0.851  1.430  2.026  1.557
# 223  ...  1.058  1.007  1.042  1.406  1.658  1.424  1.284  1.449  1.713  1.442
# 224  ...  0.061  0.061  0.061  0.061  0.061  0.061  0.061  0.061  0.061  0.061
# 225  ...  0.926  0.746  0.638  1.486  1.474  0.721  0.727  1.295  1.252  1.002
# 226  ...  0.329  0.102 -0.008  0.808  1.051  0.116  0.405  0.939  0.415 -0.101
#
# [227 rows x 56 columns]

# %%
df.isnull().sum()
# Out:
# ObjectId        0
# Country Name    0
# Unit            0
# Change          0
# 1970            0
# 1971            0
# 1972            0
# 1973            0
# 1974            0
# 1975            0
# 1976            0
# 1977            0
# 1978            0
# 1979            0
# 1980            0
# 1981            0
# 1982            0
# 1983            0
# 1984            0
# 1985            0
# 1986            0
# 1987            0
# 1988            0
# 1989            0
# 1990            0
# 1991            0
# 1992            0
# 1993            0
# 1994            0
# 1995            0
# 1996            0
# 1997            0
# 1998            0
# 1999            0
# 2000            0
# 2001            0
# 2002            0
# 2003            0
# 2004            0
# 2005            0
# 2006            0
# 2007            0
# 2008            0
# 2009            0
# 2010            0
# 2011            0
# 2012            0
# 2013            0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# dtype: int64

# %%
year_cols = [str(year) for year in range(1970, 2022)]

# %%
# Country with Highest rise of Temperature from baseline
max_val = df[year_cols].max().max()
max_year = df[year_cols].max().idxmax()   
max_country = df.loc[df[max_year].idxmax(), "Country Name"]
print("Highest rise value:", max_val)
print("Year:", max_year)
print("Country:", max_country)
# Out:
# Highest rise value: 3.693
# Year: 2020
# Country: Russian Federation

# %%
# Counrty with lowest drop of temperature form baseline
min_val = df[year_cols].min().min()
min_year = df[year_cols].min().idxmin()
min_country = df.loc[df[min_year].idxmin(), "Country Name"]
print("lowest drop value:", min_val)
print("Year:", min_year)
print("Country:", min_country)
# Out:
# lowest drop value: -2.069
# Year: 1983
# Country: Greenland

# %%
# Average change in temperature of every year
yearly_mean = df[year_cols].mean()
print(yearly_mean)
# Out:
# 1970    0.139916
# 1971   -0.099326
# 1972   -0.002145
# 1973    0.260357
# 1974   -0.075475
# 1975    0.041932
# 1976   -0.142165
# 1977    0.208672
# 1978    0.133407
# 1979    0.273631
# 1980    0.281056
# 1981    0.218178
# 1982    0.205474
# 1983    0.342979
# 1984    0.135179
# 1985    0.128429
# 1986    0.196349
# 1987    0.398817
# 1988    0.475662
# 1989    0.281656
# 1990    0.529888
# 1991    0.371295
# 1992    0.250491
# 1993    0.231572
# 1994    0.604828
# 1995    0.626257
# 1996    0.312573
# 1997    0.553971
# 1998    0.955508
# 1999    0.739149
# 2000    0.660364
# 2001    0.830604
# 2002    0.898128
# 2003    0.823527
# 2004    0.756339
# 2005    0.829903
# 2006    0.841865
# 2007    0.983833
# 2008    0.781388
# 2009    0.884557
# 2010    1.064540
# 2011    0.786952
# 2012    0.862383
# 2013    0.892383
# 2014    1.062648
# 2015    1.211907
# 2016    1.376170
# 2017    1.223640
# 2018    1.245326
# 2019    1.375469
# 2020    1.481088
# 2021    1.273696
# dtype: float64

# %%
# Average change in temperature of entire data 
global_avg_all_years = yearly_mean.mean()
print("Global Average change in temperature:",global_avg_all_years)
# Actual Global Change in temperature at present as compared to baseline temperature
# Out:
# Global Average change in temperature: 0.5908620382921045

# %%
# Every countries Average change in temperature over the period 
country_mean = df.set_index("Country Name")[year_cols].mean(axis=1)
print(country_mean)
# Out:
# Country Name
# Afghanistan, Islamic Rep. of    0.629404
# Albania                         0.568288
# Algeria                         0.799750
# American Samoa                  0.460317
# Andorra, Principality of        0.821558
#                                   ...
# Western Sahara                  0.816596
# World                           0.655923
# Yemen, Rep. of                  0.161962
# Zambia                          0.619212
# Zimbabwe                        0.271538
# Length: 227, dtype: float64

# %%
# Country with highest average rise in temperature over the year
highest_country = country_mean.idxmax()
highest_value = country_mean.max()
print(highest_country,highest_value)
# Out:
# Luxembourg 1.5798653846153852

# %%
# Country with lowest average drop in temperature over the year
lowest_country = country_mean.idxmin()
lowest_value = country_mean.min()
print(lowest_country,lowest_value)
# Out:
# Nauru, Rep. of -0.15717307692307686

# %%
## Number of countries with the temperature rise above 2 degree celcius 

year_cols = [col for col in df.columns if col.isdigit()]

# Rise relative to 1970 for each year
temp_change = df[year_cols].subtract(df["1970"], axis=0)

# The maximum rise for each country
df["max_rise"] = temp_change.max(axis=1)

# Countries with >2°C rise
countries_over_2 = df[df["max_rise"] > 2]["Country Name"]
print("Number of countries with >2°C rise:", len(countries_over_2))
print("\nCountries:\n", countries_over_2.tolist())
# Out:
# Number of countries with >2°C rise: 60
#
# Countries:
#  ['Albania', 'Algeria', 'Andorra, Principality of', 'Armenia, Rep. of', 'Austria', 'Azerbaijan, Rep. of', 'Bahamas, The', 'Bahrain, Kingdom of', 'Belarus, Rep. of', 'Bulgaria', 'Canada', 'China, P.R.: Hong Kong', 'China, P.R.: Macao', 'China, P.R.: Mainland', 'Czech Rep.', 'Denmark', 'Egypt, Arab Rep. of', 'Estonia, Rep. of', 'Faroe Islands', 'Finland', 'France', 'Georgia', 'Germany', 'Gibraltar', 'Greenland', 'Hungary', 'Iceland', 'Israel', 'Jordan', 'Kazakhstan, Rep. of', "Korea, Dem. People's Rep. of", 'Korea, Rep. of', "Lao People's Dem. Rep.", 'Libya', 'Liechtenstein', 'Malta', 'Moldova, Rep. of', 'Monaco', 'Mongolia', 'Morocco', 'Namibia', 'Netherlands, The', 'North Macedonia, Republic of ', 'Norway', 'Poland, Rep. of', 'Portugal', 'Qatar', 'Romania', 'Russian Federation', 'Slovak Rep.', 'Sweden', 'Switzerland', 'Taiwan Province of China', 'Tajikistan, Rep. of', 'Tunisia', 'Turkmenistan', 'Ukraine', 'United States', 'Uzbekistan, Rep. of', 'West Bank and Gaza']

# %%
# Linegraph of global yearly average temperature change 
plt.figure(figsize=(14,6))
plt.plot(yearly_mean.index, yearly_mean.values, marker="o")
plt.title("Global Yearly Mean Temperature Change (1970–2021)")
plt.xlabel("Year")
plt.ylabel("Temperature Change (°C)")
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
# Bargraph of global yearly average temperature change 
plt.figure(figsize=(14,6))
plt.bar(yearly_mean.index, yearly_mean.values, color="skyblue")
plt.title("Global Yearly Mean Temperature Change (1970–2021)")
plt.xlabel("Year")
plt.ylabel("Temperature Change (°C)")
plt.xticks(rotation=90)
plt.show()

# %%
# Scattered graph of country wise average temperature change
plt.figure(figsize=(14,6))
plt.scatter(country_mean.index, country_mean.values, alpha=0.7)
plt.title("Country-wise Mean Temperature Change (1970–2021)")
plt.xlabel("Country")
plt.ylabel("Mean Temperature Change (°C)")
plt.xticks([], [])
plt.show()

# %%
# Line graph of temperature change in all countries over the years 
plt.figure(figsize=(14,8))
for _, row in df.iterrows():
    plt.plot(year_cols, row[year_cols].values, alpha=0.3)
plt.title("Temperature Change Trends of All Countries (1970–2021)")
plt.xlabel("Year")
plt.ylabel("Temperature Change (°C)")
plt.xticks(rotation=90)
plt.show()

# %%
# Heatmap of countries according to average temperature change in the period 
sorted_countries = country_mean.sort_values(ascending=False)
plt.figure(figsize=(10,38))
plt.imshow(sorted_countries.values.reshape(-1,1), cmap="coolwarm", aspect="auto")
plt.colorbar(label="Mean Temperature Change (°C)")
plt.yticks(range(len(sorted_countries)), sorted_countries.index, fontsize=6)
plt.xticks([0], ["Countries"])
plt.title("Heatmap of Countries by Mean Temperature Change (1970–2021)")
plt.show()

# %%
# Barchart of top 10 most affected and bottom 10 least affected countries 
top10 = country_mean.sort_values(ascending=False).head(10)
bottom10 = country_mean.sort_values().head(10)
plt.figure(figsize=(14,6))
plt.bar(top10.index, top10.values, color="red", label="Most Affected")
plt.bar(bottom10.index, bottom10.values, color="blue", label="Least Affected")
plt.title("Top 10 and Bottom 10 Countries by Mean Temperature Change (1970–2021)")
plt.xlabel("Country")
plt.ylabel("Mean Temperature Change (°C)")
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
# Boxplot of yearly distribution of temperature change across all the countries
plt.figure(figsize=(14, 6))
plt.boxplot([df[year].dropna().values for year in year_cols])
plt.ylabel("Temperature Change (°C)")
plt.title("Yearly Distribution of Temperature Changes Across Countries")
plt.xticks(range(1, len(year_cols) + 1, 5), year_cols[::5], rotation=90) 
plt.show()

# %%
# Piechart amoung top 10 most affected countries with temperature change 
top10 = country_mean.sort_values(ascending=False).head(10)
plt.pie(top10, labels=top10.index, autopct='%1.1f%%')
plt.title("Top 10 Most Affected Countries")
plt.show()

# %%
future_years = list(range(2022, 2051))  
results = []

# %%
### Prediction done using Linear regression ML model continuing with the same trend till the year 2050

for i, row in df.iterrows():
    country = row['Country Name']
    y = np.array([int(y) for y in year_cols]).reshape(-1, 1)
    values = row[year_cols].values

    # Training model
    X_train, X_test, y_train, y_test = train_test_split(y, values, test_size=0.2, random_state=42)
    lin_reg = LinearRegression()
    lin_reg.fit(X_train, y_train)

    # Predicting future
    future_X = np.array(future_years).reshape(-1, 1)
    future_preds = lin_reg.predict(future_X)

    # Storeing results 
    result = {"Country": country}
    for year, pred in zip(future_years, future_preds):
        result[str(year)] = pred

    results.append(result)

# %%
pred_df = pd.DataFrame(results)
print(pred_df.head())
# Out:
#                         Country      2022      2023      2024      2025  \
# 0  Afghanistan, Islamic Rep. of  1.325951  1.351707  1.377463  1.403220
# 1                       Albania  1.730657  1.773822  1.816988  1.860153
# 2                       Algeria  1.864556  1.904826  1.945096  1.985366
# 3                American Samoa  0.925525  0.943531  0.961536  0.979542
# 4      Andorra, Principality of  1.887829  1.929796  1.971763  2.013729
#
#        2026      2027      2028      2029      2030  ...      2041      2042  \
# 0  1.428976  1.454733  1.480489  1.506246  1.532002  ...  1.815322  1.841079
# 1  1.903319  1.946484  1.989649  2.032815  2.075980  ...  2.550799  2.593965
# 2  2.025637  2.065907  2.106177  2.146447  2.186717  ...  2.629687  2.669957
# 3  0.997547  1.015553  1.033558  1.051564  1.069570  ...  1.267631  1.285636
# 4  2.055696  2.097663  2.139630  2.181597  2.223564  ...  2.685200  2.727167
#
#        2043      2044      2045      2046      2047      2048      2049  \
# 0  1.866835  1.892592  1.918348  1.944105  1.969861  1.995617  2.021374
# 1  2.637130  2.680296  2.723461  2.766626  2.809792  2.852957  2.896122
# 2  2.710227  2.750497  2.790767  2.831037  2.871307  2.911577  2.951848
# 3  1.303642  1.321647  1.339653  1.357658  1.375664  1.393669  1.411675
# 4  2.769134  2.811100  2.853067  2.895034  2.937001  2.978968  3.020935
#
#        2050
# 0  2.047130
# 1  2.939288
# 2  2.992118
# 3  1.429681
# 4  3.062902
#
# [5 rows x 30 columns]

# %%
pred_df
# Out:
#                           Country      2022      2023      2024      2025  \
# 0    Afghanistan, Islamic Rep. of  1.325951  1.351707  1.377463  1.403220
# 1                         Albania  1.730657  1.773822  1.816988  1.860153
# 2                         Algeria  1.864556  1.904826  1.945096  1.985366
# 3                  American Samoa  0.925525  0.943531  0.961536  0.979542
# 4        Andorra, Principality of  1.887829  1.929796  1.971763  2.013729
# ..                            ...       ...       ...       ...       ...
# 222                Western Sahara  1.765095  1.802255  1.839415  1.876575
# 223                         World  1.498667  1.530878  1.563090  1.595302
# 224                Yemen, Rep. of  0.034706  0.029311  0.023916  0.018521
# 225                        Zambia  1.279293  1.304918  1.330543  1.356168
# 226                      Zimbabwe  0.480632  0.489884  0.499136  0.508388
#
#          2026      2027      2028      2029      2030  ...      2041  \
# 0    1.428976  1.454733  1.480489  1.506246  1.532002  ...  1.815322
# 1    1.903319  1.946484  1.989649  2.032815  2.075980  ...  2.550799
# 2    2.025637  2.065907  2.106177  2.146447  2.186717  ...  2.629687
# 3    0.997547  1.015553  1.033558  1.051564  1.069570  ...  1.267631
# 4    2.055696  2.097663  2.139630  2.181597  2.223564  ...  2.685200
# ..        ...       ...       ...       ...       ...  ...       ...
# 222  1.913735  1.950895  1.988054  2.025214  2.062374  ...  2.471132
# 223  1.627514  1.659725  1.691937  1.724149  1.756360  ...  2.110689
# 224  0.013125  0.007730  0.002335 -0.003060 -0.008456  ... -0.067804
# 225  1.381793  1.407418  1.433043  1.458668  1.484293  ...  1.766169
# 226  0.517639  0.526891  0.536143  0.545395  0.554647  ...  0.656416
#
#          2042      2043      2044      2045      2046      2047      2048  \
# 0    1.841079  1.866835  1.892592  1.918348  1.944105  1.969861  1.995617
# 1    2.593965  2.637130  2.680296  2.723461  2.766626  2.809792  2.852957
# 2    2.669957  2.710227  2.750497  2.790767  2.831037  2.871307  2.911577
# 3    1.285636  1.303642  1.321647  1.339653  1.357658  1.375664  1.393669
# 4    2.727167  2.769134  2.811100  2.853067  2.895034  2.937001  2.978968
# ..        ...       ...       ...       ...       ...       ...       ...
# 222  2.508292  2.545452  2.582612  2.619772  2.656932  2.694091  2.731251
# 223  2.142901  2.175113  2.207324  2.239536  2.271748  2.303959  2.336171
# 224 -0.073199 -0.078594 -0.083989 -0.089385 -0.094780 -0.100175 -0.105570
# 225  1.791794  1.817419  1.843044  1.868669  1.894294  1.919919  1.945544
# 226  0.665668  0.674920  0.684171  0.693423  0.702675  0.711927  0.721178
#
#          2049      2050
# 0    2.021374  2.047130
# 1    2.896122  2.939288
# 2    2.951848  2.992118
# 3    1.411675  1.429681
# 4    3.020935  3.062902
# ..        ...       ...
# 222  2.768411  2.805571
# 223  2.368383  2.400595
# 224 -0.110966 -0.116361
# 225  1.971169  1.996794
# 226  0.730430  0.739682
#
# [227 rows x 30 columns]

# %%
# Average predicted temperature change form year 2022 to 2050 
mean_per_year = pred_df[[str(y) for y in future_years]].mean()
mean_df = mean_per_year.reset_index()
mean_df.columns = ["Year", "Mean_Temp_Change"]
print(mean_df)
# Out:
#     Year  Mean_Temp_Change
# 0   2022          1.317374
# 1   2023          1.345041
# 2   2024          1.372707
# 3   2025          1.400373
# 4   2026          1.428039
# 5   2027          1.455706
# 6   2028          1.483372
# 7   2029          1.511038
# 8   2030          1.538705
# 9   2031          1.566371
# 10  2032          1.594037
# 11  2033          1.621703
# 12  2034          1.649370
# 13  2035          1.677036
# 14  2036          1.704702
# 15  2037          1.732369
# 16  2038          1.760035
# 17  2039          1.787701
# 18  2040          1.815367
# 19  2041          1.843034
# 20  2042          1.870700
# 21  2043          1.898366
# 22  2044          1.926033
# 23  2045          1.953699
# 24  2046          1.981365
# 25  2047          2.009032
# 26  2048          2.036698
# 27  2049          2.064364
# 28  2050          2.092030

# %%
# Predicted highly affected country due to temperature change by the year 2050
max_row = pred_df.loc[pred_df["2050"].idxmax()]
highest_country = max_row["Country"]
highest_value = max_row["2050"]
print(highest_country,highest_value)
# Out:
# Armenia, Rep. of 4.656524414978804

# %%
# Predicted least affected country due to temperature change by the year 2050
min_row = pred_df.loc[pred_df["2050"].idxmin()]
lowest_country = min_row["Country"]
lowest_value = min_row["2050"]
print(lowest_country,lowest_value)
# Out:
# Nauru, Rep. of -0.6027580863555926

# %%
## predicted number of countries with the temperature rise above 2 degree celcius by the year 2050 

baseline = df[["Country Name", "1970"]].rename(columns={"1970": "baseline"})
merged = pred_df.merge(baseline, left_on="Country", right_on="Country Name")
merged["rise_2050"] = merged["2050"] - merged["baseline"]
countries_over_2_2050 = merged[merged["rise_2050"] > 2]["Country"]

print("Number of countries with >2°C rise in 2050:", len(countries_over_2_2050))
print("\nCountries:\n", countries_over_2_2050.tolist())
# Out:
# Number of countries with >2°C rise in 2050: 99
#
# Countries:
#  ['Albania', 'Algeria', 'Andorra, Principality of', 'Angola', 'Armenia, Rep. of', 'Austria', 'Azerbaijan, Rep. of', 'Bahamas, The', 'Bahrain, Kingdom of', 'Brazil', 'Bulgaria', 'Burundi', 'Cabo Verde', 'Canada', 'China, P.R.: Hong Kong', 'China, P.R.: Macao', 'China, P.R.: Mainland', 'Congo, Dem. Rep. of the', 'Cuba', 'Cyprus', 'Czech Rep.', 'Denmark', 'Djibouti', 'Dominican Rep.', 'Egypt, Arab Rep. of', 'Ethiopia, The Federal Dem. Rep. of', 'Faroe Islands', 'Finland', 'France', 'Gambia, The', 'Georgia', 'Germany', 'Gibraltar', 'Greece', 'Greenland', 'Guatemala', 'Guinea-Bissau', 'Haiti', 'Holy See', 'Hungary', 'Iceland', 'Iraq', 'Israel', 'Italy', 'Japan', 'Jordan', 'Kazakhstan, Rep. of', 'Kiribati', "Korea, Dem. People's Rep. of", 'Korea, Rep. of', 'Kuwait', 'Kyrgyz Rep.', "Lao People's Dem. Rep.", 'Lebanon', 'Libya', 'Liechtenstein', 'Malta', 'Mexico', 'Moldova, Rep. of', 'Monaco', 'Mongolia', 'Morocco', 'Myanmar', 'Namibia', 'Netherlands, The', 'Niger', 'North Macedonia, Republic of ', 'Norway', 'Poland, Rep. of', 'Portugal', 'Qatar', 'Romania', 'Russian Federation', 'Rwanda', 'Saint Helena', 'San Marino, Rep. of', 'Saudi Arabia', 'Slovak Rep.', 'Somalia', 'Spain', 'Suriname', 'Sweden', 'Switzerland', 'Syrian Arab Rep.', 'Taiwan Province of China', 'Tajikistan, Rep. of', 'Thailand', 'Tokelau', 'Tunisia', 'Turkmenistan', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United States', 'Uzbekistan, Rep. of', 'Vietnam', 'West Bank and Gaza', 'Western Sahara', 'World']

# %%
## Linegraph of average per year change in temperature of the given data followed by predicted data 

historical_years = [str(y) for y in range(1970, 2022)]
historical_mean = df[historical_years].mean()

future_mean = pred_df[[str(y) for y in future_years]].mean()

plt.figure(figsize=(18,6))
plt.plot(historical_mean.index, historical_mean.values, color="blue", label="Historical (1970–2021)")
plt.plot(future_mean.index, future_mean.values, color="red", label="Predicted (2022–2050)")

plt.axhline(2, color="gray", linestyle="--", label="2°C Threshold")
plt.title("Global Mean Temperature Change (1970–2050)")
plt.xlabel("Year")
plt.ylabel("Mean Temperature Change (°C)")
plt.legend()
plt.grid(True)
plt.xticks(rotation=90)
plt.show()

# %%
# Nepals 2050 temperature change prediction form baseline
nepal_2050 = pred_df.loc[pred_df["Country"] == "Nepal", "2050"].values[0]
print("Nepal's predicted temperature change in 2050:", nepal_2050)
# Out:
# Nepal's predicted temperature change in 2050: 1.3788334354018659
